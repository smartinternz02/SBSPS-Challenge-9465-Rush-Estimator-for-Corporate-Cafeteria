# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Log.csv')
df
# Out:
#                     Time  In  Out  Totalmember
# 0   23/09/2022, 20:24:14   1  NaN          2.0
# 1                    NaN   2  NaN          NaN
# 2   23/09/2022, 20:24:15   1  NaN          3.0
# 3                    NaN   2  NaN          NaN
# 4                    NaN   3  NaN          NaN
# 5   23/09/2022, 20:24:15   1  NaN          4.0
# 6                    NaN   2  NaN          NaN
# 7                    NaN   3  NaN          NaN
# 8                    NaN   4  NaN          NaN
# 9   23/09/2022, 20:24:20   1  1.0          3.0
# 10                   NaN   2  NaN          NaN
# 11                   NaN   3  NaN          NaN
# 12                   NaN   4  NaN          NaN
# 13  23/09/2022, 20:24:21   1  1.0          2.0
# 14                   NaN   2  2.0          NaN
# 15                   NaN   3  NaN          NaN
# 16                   NaN   4  NaN          NaN
# 17  23/09/2022, 20:24:23   1  1.0          3.0
# 18                   NaN   2  2.0          NaN
# ...

# %%
df.Totalmember
# Out:
# 0     2.0
# 1     NaN
# 2     3.0
# 3     NaN
# 4     NaN
# 5     4.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     3.0
# 10    NaN
# 11    NaN
# 12    NaN
# 13    2.0
# 14    NaN
# 15    NaN
# 16    NaN
# 17    3.0
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    2.0
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    3.0
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    4.0
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# Name: Totalmember, dtype: float64

# %%
# %matplotlib inline
plt.xlabel('Time')
plt.ylabel('Total members')
plt.scatter(df.Time,df.Totalmember,color='red',marker='+')

# %%
new_data = df.drop('Totalmember',axis = "columns")
new_data
# Out:
#                     Time  In  Out
# 0   23/09/2022, 20:24:14   1  NaN
# 1                    NaN   2  NaN
# 2   23/09/2022, 20:24:15   1  NaN
# 3                    NaN   2  NaN
# 4                    NaN   3  NaN
# 5   23/09/2022, 20:24:15   1  NaN
# 6                    NaN   2  NaN
# 7                    NaN   3  NaN
# 8                    NaN   4  NaN
# 9   23/09/2022, 20:24:20   1  1.0
# 10                   NaN   2  NaN
# 11                   NaN   3  NaN
# 12                   NaN   4  NaN
# 13  23/09/2022, 20:24:21   1  1.0
# 14                   NaN   2  2.0
# 15                   NaN   3  NaN
# 16                   NaN   4  NaN
# 17  23/09/2022, 20:24:23   1  1.0
# 18                   NaN   2  2.0
# 19                   NaN   3  NaN
# 20                   NaN   4  NaN
# 21                   NaN   5  NaN
# 22  23/09/2022, 20:24:29   1  1.0
# 23                   NaN   2  2.0
# 24                   NaN   3  3.0
# 25                   NaN   4  NaN
# ...

# %% [markdown]
# price = df.Totalmember
# price

# %%
df['Time'].fillna(method='pad', inplace=True)
df
# Out:
#                     Time  In  Out  Totalmember
# 0   23/09/2022, 20:24:14   1  NaN          2.0
# 1   23/09/2022, 20:24:14   2  NaN          NaN
# 2   23/09/2022, 20:24:15   1  NaN          3.0
# 3   23/09/2022, 20:24:15   2  NaN          NaN
# 4   23/09/2022, 20:24:15   3  NaN          NaN
# 5   23/09/2022, 20:24:15   1  NaN          4.0
# 6   23/09/2022, 20:24:15   2  NaN          NaN
# 7   23/09/2022, 20:24:15   3  NaN          NaN
# 8   23/09/2022, 20:24:15   4  NaN          NaN
# 9   23/09/2022, 20:24:20   1  1.0          3.0
# 10  23/09/2022, 20:24:20   2  NaN          NaN
# 11  23/09/2022, 20:24:20   3  NaN          NaN
# 12  23/09/2022, 20:24:20   4  NaN          NaN
# 13  23/09/2022, 20:24:21   1  1.0          2.0
# 14  23/09/2022, 20:24:21   2  2.0          NaN
# 15  23/09/2022, 20:24:21   3  NaN          NaN
# 16  23/09/2022, 20:24:21   4  NaN          NaN
# 17  23/09/2022, 20:24:23   1  1.0          3.0
# 18  23/09/2022, 20:24:23   2  2.0          NaN
# ...

# %%
dnf = pd.DataFrame({'time':df.Time })
dnf = dnf.time = pd.to_datetime(dnf.time)
dnf
# Out:
# 0    2022-09-23 20:24:14
# 1    2022-09-23 20:24:14
# 2    2022-09-23 20:24:15
# 3    2022-09-23 20:24:15
# 4    2022-09-23 20:24:15
# 5    2022-09-23 20:24:15
# 6    2022-09-23 20:24:15
# 7    2022-09-23 20:24:15
# 8    2022-09-23 20:24:15
# 9    2022-09-23 20:24:20
# 10   2022-09-23 20:24:20
# 11   2022-09-23 20:24:20
# 12   2022-09-23 20:24:20
# 13   2022-09-23 20:24:21
# 14   2022-09-23 20:24:21
# 15   2022-09-23 20:24:21
# 16   2022-09-23 20:24:21
# 17   2022-09-23 20:24:23
# 18   2022-09-23 20:24:23
# 19   2022-09-23 20:24:23
# 20   2022-09-23 20:24:23
# 21   2022-09-23 20:24:23
# 22   2022-09-23 20:24:29
# 23   2022-09-23 20:24:29
# 24   2022-09-23 20:24:29
# 25   2022-09-23 20:24:29
# 26   2022-09-23 20:24:29
# 27   2022-09-23 20:24:29
# 28   2022-09-23 20:24:29
# 29   2022-09-23 20:24:29
# 30   2022-09-23 20:24:29
# 31   2022-09-23 20:24:29
# 32   2022-09-23 20:24:29
# 33   2022-09-23 20:24:29
# 34   2022-09-23 20:24:29
# 35   2022-09-23 20:24:29
# 36   2022-09-23 20:24:29
# ...

# %%
df['Totalmember'].fillna(method='pad', inplace=True)
totalmember = df.Totalmember
totalmember
# Out:
# 0     2.0
# 1     2.0
# 2     3.0
# 3     3.0
# 4     3.0
# 5     4.0
# 6     4.0
# 7     4.0
# 8     4.0
# 9     3.0
# 10    3.0
# 11    3.0
# 12    3.0
# 13    2.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    3.0
# 18    3.0
# 19    3.0
# 20    3.0
# 21    3.0
# 22    2.0
# 23    2.0
# 24    2.0
# 25    2.0
# 26    2.0
# 27    3.0
# 28    3.0
# 29    3.0
# 30    3.0
# 31    3.0
# 32    3.0
# 33    4.0
# 34    4.0
# 35    4.0
# 36    4.0
# 37    4.0
# 38    4.0
# 39    4.0
# Name: Totalmember, dtype: float64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(dnf.values.reshape(-1,1),totalmember)
# Out:
# LinearRegression()

# %%
test = dnf.iloc[3]
test
# Out:
# Timestamp('2022-09-23 20:24:15')

# %% [markdown]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.predict(test.values.astype(float).reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-80b59e8af75f> in <module>
# ----> 1 reg.predict(test.values.astype(float).reshape(-1, 1))
#
# AttributeError: 'Timestamp' object has no attribute 'values'
